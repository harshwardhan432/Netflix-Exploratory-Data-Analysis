# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Analysing basic metrics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# # Non-Graphical Analysis: Value counts and unique attributes

# %%
df['title'].value_counts()
# Out:
# Dick Johnson Is Dead                     1
# Ip Man 2                                 1
# Hannibal Buress: Comedy Camisado         1
# Turbo FAST                               1
# Masha's Tales                            1
#                                         ..
# Love for Sale 2                          1
# ROAD TO ROMA                             1
# Good Time                                1
# Captain Underpants Epic Choice-o-Rama    1
# Zubaan                                   1
# Name: title, Length: 8807, dtype: int64

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# # pre-processing of data

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df['country']=df['country'].str.split(', ')
df=df.explode('country')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df['director']=df['director'].str.split(', ')
df=df.explode('director')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df['listed_in']=df['listed_in'].str.split(', ')
df=df.explode('listed_in')
df.head()
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 1      s2  TV Show         Blood & Water              NaN
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration               listed_in  \
# 0  September 25, 2021          2020  PG-13     90 min           Documentaries
# ...

# %%
df['cast']=df['cast'].str.split(', ')
df=df.explode('cast')
df.head()
# Out:
#   show_id     type                 title         director            cast  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson             NaN
# 1      s2  TV Show         Blood & Water              NaN      Ama Qamata
# 1      s2  TV Show         Blood & Water              NaN     Khosi Ngema
# 1      s2  TV Show         Blood & Water              NaN   Gail Mabalane
# 1      s2  TV Show         Blood & Water              NaN  Thabang Molaba
#
#          country          date_added  release_year rating   duration  \
# 0  United States  September 25, 2021          2020  PG-13     90 min
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
#
#                 listed_in                                        description
# ...

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'],inplace=True)

# %%
df.head()
# Out:
#   show_id     type                 title         director            cast  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson             NaN
# 1      s2  TV Show         Blood & Water              NaN      Ama Qamata
# 2      s2  TV Show         Blood & Water              NaN     Khosi Ngema
# 3      s2  TV Show         Blood & Water              NaN   Gail Mabalane
# 4      s2  TV Show         Blood & Water              NaN  Thabang Molaba
#
#          country          date_added  release_year rating   duration  \
# 0  United States  September 25, 2021          2020  PG-13     90 min
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 3   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 4   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
#
#                 listed_in                                        description
# ...

# %%
for i in df.columns:
    null_rate = df[i].isna().sum()/len(df) * 100
    if null_rate >= 0 :
        print("{} null rate: {}%".format(i,round(null_rate,2)))
# Out:
# show_id null rate: 0.0%
# type null rate: 0.0%
# title null rate: 0.0%
# director null rate: 25.07%
# cast null rate: 1.06%
# country null rate: 5.89%
# date_added null rate: 0.08%
# release_year null rate: 0.0%
# rating null rate: 0.03%
# duration null rate: 0.0%
# listed_in null rate: 0.0%
# description null rate: 0.0%

# %% [markdown]
# ## Imputing categorical values using value_counts

# %%
df['director'] = df['director'].fillna(df.groupby('country')['director'].value_counts().index[0][1])

# %%
df['cast']=df['cast'].fillna(df.groupby('country')['cast'].value_counts().iloc[0])

# %%
df['country']=df['country'].fillna(df.groupby('cast')['country'].value_counts().iloc[0])

# %%
df['date_added']=df['date_added'].fillna(df.groupby('country')['date_added'].value_counts().iloc[0])

# %%
df['rating']=df['rating'].fillna(df.groupby('country')['rating'].value_counts().iloc[0])

# %%
df['duration']=df['duration'].fillna(df.groupby('country')['duration'].value_counts().iloc[0])

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                 title         director            cast  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson               3
# 1      s2  TV Show         Blood & Water     Najwa Najjar      Ama Qamata
# 2      s2  TV Show         Blood & Water     Najwa Najjar     Khosi Ngema
# 3      s2  TV Show         Blood & Water     Najwa Najjar   Gail Mabalane
# 4      s2  TV Show         Blood & Water     Najwa Najjar  Thabang Molaba
#
#          country date_added  release_year rating duration  \
# 0  United States 2021-09-25          2020  PG-13       90
# 1   South Africa 2021-09-24          2021  TV-MA       2
# 2   South Africa 2021-09-24          2021  TV-MA       2
# 3   South Africa 2021-09-24          2021  TV-MA       2
# 4   South Africa 2021-09-24          2021  TV-MA       2
#
#                 listed_in                                        description
# 0           Documentaries  As her father nears the end of his life, filmm...
# ...

# %%
df['date_added']=pd.to_datetime(df['date_added'])

# %%
df['duration']=df['duration'].str.replace(' min','')

# %%
df['duration']=df['duration'].str.replace('Seasons','')

# %%
df['duration']=df['duration'].str.replace('Season','')

# %%
df['duration']=df['duration'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201991 entries, 0 to 201990
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       201991 non-null  object
#  1   type          201991 non-null  object
#  2   title         201991 non-null  object
#  3   director      201991 non-null  object
#  4   cast          201991 non-null  object
#  5   country       201991 non-null  object
#  6   date_added    201991 non-null  datetime64[ns]
#  7   release_year  201991 non-null  int64
#  8   rating        201991 non-null  object
#  9   duration      201991 non-null  int32
#  10  listed_in     201991 non-null  object
#  11  description   201991 non-null  object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(9)
# memory usage: 17.7+ MB

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df,x='type')
plt.show()

# %%
sns.displot(data=df,x='release_year',kind='kde',hue='type')
plt.figure(figsize=(1,1))
plt.show()

# %%
df['listed_in'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
sns.pairplot(data=df,hue='type')
plt.show()

# %%
sns.heatmap(df[['release_year','duration']].corr(),annot=True)
plt.show()

# %%
sns.boxplot(data=df,x='type',y='release_year')
plt.show()

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', 4590,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['release_year'].unique()
# Out:
# array([2020, 2021, 1993, 2018, 1996, 1998, 1997, 2010, 2013, 2017, 1975,
#        1978, 1983, 1987, 2012, 2001, 2014, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 2019, 2016, 1982, 1989, 1990,
#        1991, 1999, 1986, 1992, 1984, 1980, 1961, 2000, 1995, 1985, 1976,
#        1959, 1988, 1981, 1972, 1964, 1945, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1925, 1974, 1960, 1966, 1971, 1962, 1969, 1977, 1967,
#        1968, 1965, 1946, 1942, 1955, 1944, 1947, 1943], dtype=int64)

# %%
df['title'].unique()
# Out:
# array(['Dick Johnson Is Dead', 'Blood & Water', 'Ganglands', ...,
#        'Zombieland', 'Zoom', 'Zubaan'], dtype=object)

# %%
df['cast']=df['cast'].replace(3,'Tom Cruise')

# %%
df['country']=df['country'].replace(742,'United States')

# %%
df['country'].value_counts().head().plot.bar()
# Out:
# <Axes: >

# %%
df['director'].value_counts().head().plot.bar()
# Out:
# <Axes: >

# %%
df['cast'].value_counts().head().plot.bar()
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x='duration',y='date_added',hue='type')
plt.show()

# %% [markdown]
# ## India specific insights

# %%
ind=df[df['country']=='India']

# %%
sns.countplot(data=ind,y='listed_in')
plt.show()

# %%
sns.displot(data=ind,x='duration',hue='type')
plt.title('duration distribution of Movies and TV series in India')
plt.show()

# %%
sns.catplot(data=ind,x='release_year',kind='boxen')
plt.ylabel('Movies')
plt.show()

# %%
sns.countplot(data=ind,x='type')
plt.show()

# %%
ind['director'].value_counts().head(10).plot.bar()
# Out:
# <Axes: >

# %%
ind['cast'].value_counts().head(10).plot.bar()
# Out:
# <Axes: >

# %%
ind['listed_in'].value_counts().head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # Business Insights

# %% [markdown]
# ### 1.) The top two country of origin is USA and India, so more focus on movies/TV series from this origin
# ### 2.) International Movies, Dramas, Comedies are the most popular genres of streaming
# ### 3.) Movies are more watched than TV shows.
# ### 4.) Release year is thickly concentrated between 2010 to 2020.
# ### 5.) Most watched TV shows have season length of 1 to 2 seasons and Movies have duration range of 70-200                  mins.
# ### 6.) Najwa Najjar is the most appeared director globally and David Dhawan is the most appeared director in                     India.
# ### 7.) Anupam Kher is the most appeared actor in India while Adam Sandler is the most appeared actor globally.
